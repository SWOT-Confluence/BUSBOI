# %%
suppressMessages({
    library(dplyr)
library(ggplot2)
library(tidyr)
library(hydroGOF)
    })

# %%
gauge_df=readRDS('/nas/cee-water/cjgleason/colin/analyze confluence runs/devset_gauges.RDS')
gauged_reaches=unique(gauge_df$reach_id)
swot_base='/nas/cee-water/cjgleason/ellie/SWOT/confluence/confluence_relPermML/relPermML_mnt/input/swot/'
sos_base='/nas/cee-water/cjgleason/ellie/SWOT/confluence/confluence_relPermML/relPermML_mnt/input/sos/'
reach_ids=gauged_reaches[gauged_reaches %in% substr(list.files(swot_base),1,11)]

# %%
output_path='/nas/cee-water/cjgleason/colin/neobam/test_tulip_nogvf/'

# %%
run= substr(list.files(output_path),1,11)
unrun = !(reach_ids %in% run)
sum(unrun)
# Out:
# [1] 1531

# %%
stopCluster(clust)

# %%
source('/nas/cee-water/cjgleason/colin/neobam/neobam/main_function.R')

# a=Sys.time()
# library(parallel)
# clust=makeCluster(90)

suppressWarnings({
for (i in 2){
test= main_function(reach_ids[i],
                   output_path=output_path,
                   swot_base=swot_base,
                   sos_base=sos_base,
                   Q_prior='daily',
                   GVF_on=0,
                   fix_bed=0) # 0 = 5 pt, 1 = 1pt, 2 = fixed
    }
})

# test=parLapply(clust,reach_ids[unrun][1:750],batch_neobam,
#                    output_path=output_path,
#                    swot_base=swot_base,
#                    sos_base=sos_base,
#                 Q_prior='daily',
#                    GVF_on=1,
#                    fix_bed=0)
# stopCluster(clust)
# print(Sys.time()-a)
# Out:
# [[1]]
#
# [[2]]
# plot without title
# [[3]]
# plot without title
# [[4]]
# plot without title
# [[5]]
# plot without title
# [[6]]
# plot without title
# [[7]]
# plot without title
# [[8]]
# plot without title
# [[9]]
# plot without title
# [[10]]
# plot without title
# [[11]]
# plot without title
# [[12]]
# plot without title
# [[13]]
# plot without title
# [[14]]
# plot without title
# [[15]]
# plot without title
# Error in jeff_calcHgivenparams(variables = optparams$par, hyperparams = hyperparams, : object 'bonk' not found
# Traceback:
#
# 1. withCallingHandlers(expr, warning = function(w) if (inherits(w,
#  .     classes)) tryInvokeRestart("muffleWarning"))
# 2. main_function(reach_ids[i], output_path = output_path, swot_base = swot_base,
#  .     sos_base = sos_base, Q_prior = "daily", GVF_on = 0, fix_bed = 0)
# 3. run_neobam(this_reach_id, priors = neobam_data_object$priors,
#  .     data = neobam_data_object$swot_data, fix_bed = fix_bed, GVF_on = GVF_on,
#  .     Q_priors = neobam_data_object$Qpriors)
# 4. jeff_solver(this_reach_id, priors, data, Q_priors, fix_bed, GVF_on)
# 5. jeff_calcHgivenparams(variables = optparams$par, hyperparams = hyperparams,
#  .     plot_switch = 1, this_reach_id = this_reach_id, obj_error = obj_error,
#  .     replacement_error = replacement_error, smooth_sf = smooth_sf,
#  .     Qpenalty = Qpenalty, Sfpenalty = Sfpenalty, GVF_on = GVF_on,
#  .     H_DS_init = H_DS_init, fix_bed = fix_bed)
# 6. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = invokeRestart("eval_error",
#  .             cnd))
#  . }, "object 'bonk' not found", base::quote(jeff_calcHgivenparams(variables = optparams$par,
#  .     hyperparams = hyperparams, plot_switch = 1, this_reach_id = this_reach_id,
#  .     obj_error = obj_error, replacement_error = replacement_error,
#  .     smooth_sf = smooth_sf, Qpenalty = Qpenalty, Sfpenalty = Sfpenalty,
#  .     GVF_on = GVF_on, H_DS_init = H_DS_init, fix_bed = fix_bed)))
# plot without title

# %%
# ###to control where the slurm files are written
# working_dir='/nas/cee-water/cjgleason/colin/neobam/debug_logs/'
# setwd(working_dir)
# source('/nas/cee-water/cjgleason/colin/neobam/neobam/process.R')
# #batch_neobam=function(this_reach_id,swot_base,sos_base){}

# library(rslurm, lib.loc = "/nas/cee-water/cjgleason/r-lib/",quietly = TRUE)
# library(whisker, lib.loc = "/nas/cee-water/cjgleason/r-lib/",quietly = TRUE)

# testname='daily prior GVF'

# #slurm block
# slurm_options= list(mem=128000, 'time'='50:00:00', #options for memory, time, parition, and an error file
#                     partition ='ceewater_cjgleason-cpu',
#                     error='slurm-%A_%a.err')
#                     # exclude='ceewater-cpu009')

# sjob <- slurm_map(as.list(reach_ids[unrun][751:1531]), #thing you want to loop over. must be a list
#                   batch_neobam,  # name of the function. declared above with the 'source' command
#                   jobname = testname, # defined above. just for convenience
#                    output_path=output_path,
#                    swot_base=swot_base,
#                    sos_base=sos_base,
#                   Q_prior='daily',
#                   GVF_on=0,
#                   fix_bed=0,  #0 = 5pts, 1= 1pt, 2 = fixed
#                   nodes = 1, # many nodes do you want?
#                   preschedule_cores=FALSE, # keep this FALSE
#                   cpus_per_node = 100, # how many CPUS per node. 
#                   submit = TRUE, # if TRUE, submits to the cluster
#                   slurm_options=slurm_options, #defined above
#                   libPaths="/nas/cee-water/cjgleason/r-lib/" ) #library paths
# Out:
# Submitted batch job 48684331
